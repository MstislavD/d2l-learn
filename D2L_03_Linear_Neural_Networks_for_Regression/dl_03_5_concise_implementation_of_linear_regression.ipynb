# %%
import torch
from d2l import torch as d2l

# %% [markdown]
# ### Training

# %%
model = d2l.LinearRegression(lr=0.03)
data = d2l.SyntheticRegressionData(w=torch.tensor([2, -3.4]), b=4.2)
trainer = d2l.Trainer(max_epochs=3)
trainer.fit(model, data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model = torch.nn.LinearRegression(lr=0.03)
#       2 data = d2l.SyntheticRegressionData(w=torch.tensor([2, -3.4]), b=4.2)
#       3 trainer = d2l.Trainer(max_epochs=3)
#
# AttributeError: module 'torch.nn' has no attribute 'LinearRegression'
