# %%
from d2l import torch as d2l

d2l.use_svg_display()

# %% [markdown]
# ### Loading the Dataset

# %%
data = d2l.FashionMNIST(resize=(32, 32))
len(data.train), len(data.val)
# Out:
# 100%|██████████| 26.4M/26.4M [00:05<00:00, 4.62MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 730kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 4.12MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 29.6MB/s]
# (60000, 10000)

# %%
data.train[0][0].shape
# Out:
# torch.Size([1, 32, 32])
